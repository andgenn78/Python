# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
games = pd.read_csv('vgames.csv')

# %%
games.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.68     12.76      3.79         3.29         35.52
# 3  Nintendo     15.61     10.93      3.28         2.95         32.77
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
# 5  Nintendo     23.20      2.26      4.22         0.58         30.26
# 6  Nintendo     11.28      9.14      6.50         2.88         29.80
# 7  Nintendo     13.96      9.18      2.93         2.84         28.92
# 8  Nintendo     14.44      6.94      4.70         2.24         28.32
# 9  Nintendo     26.93      0.63      0.28         0.47         28.31
#
#    Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0          76.0          51.0         8.0       322.0  Nintendo      E
# 1           NaN           NaN         NaN         NaN       NaN    NaN
# 2          82.0          73.0         8.3       709.0  Nintendo      E
# 3          80.0          73.0         8.0       192.0  Nintendo      E
# 4           NaN           NaN         NaN         NaN       NaN    NaN
# 5           NaN           NaN         NaN         NaN       NaN    NaN
# 6          89.0          65.0         8.5       431.0  Nintendo      E
# 7          58.0          41.0         6.6       129.0  Nintendo      E
# 8          87.0          80.0         8.4       594.0  Nintendo      E
# 9           NaN           NaN         NaN         NaN       NaN    NaN

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %%
games.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
games[games['Critic_Score'].isna()]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# 5          Nintendo     23.20      2.26      4.22         0.58         30.26
# 9          Nintendo     26.93      0.63      0.28         0.47         28.31
# 10         Nintendo      9.05     10.95      1.93         2.74         24.67
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# 5               NaN           NaN         NaN         NaN       NaN    NaN
# 9               NaN           NaN         NaN         NaN       NaN    NaN
# 10              NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [8582 rows x 16 columns]

# %%
games[games['Rating'].isna()]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# 5          Nintendo     23.20      2.26      4.22         0.58         30.26
# 9          Nintendo     26.93      0.63      0.28         0.47         28.31
# 10         Nintendo      9.05     10.95      1.93         2.74         24.67
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# 5               NaN           NaN         NaN         NaN       NaN    NaN
# 9               NaN           NaN         NaN         NaN       NaN    NaN
# 10              NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
# [6769 rows x 16 columns]

# %%
games[games['Year_of_Release'].isna()]
# Out:
#                                     Name Platform  Year_of_Release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16376  PDC World Championship Darts 2008      PSP              NaN
# 16409                      Freaky Flyers       GC              NaN
# 16452                          Inversion       PC              NaN
# 16462        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16526                       Virtua Quest       GC              NaN
#
#               Genre                               Publisher  NA_Sales  \
# 183          Sports                         Electronic Arts      4.26
# 377          Sports                         Electronic Arts      0.59
# 456          Action  Warner Bros. Interactive Entertainment      1.80
# 475        Fighting                                     NaN      1.57
# 609         Shooter                                   Atari      2.36
# ...             ...                                     ...       ...
# 16376        Sports                      Oxygen Interactive      0.01
# 16409        Racing                                 Unknown      0.01
# 16452       Shooter                      Namco Bandai Games      0.01
# 16462     Adventure                                 Unknown      0.01
# 16526  Role-Playing                                 Unknown      0.01
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 183        0.26      0.01         0.71          5.23          94.0
# 377        2.36      0.04         0.51          3.49          84.0
# 456        0.97      0.00         0.29          3.06          74.0
# 475        1.02      0.00         0.41          3.00           NaN
# 609        0.14      0.00         0.03          2.53           NaN
# ...         ...       ...          ...           ...           ...
# 16376      0.00      0.00         0.00          0.01          43.0
# 16409      0.00      0.00         0.00          0.01          69.0
# 16452      0.00      0.00         0.00          0.01          59.0
# 16462      0.00      0.00         0.00          0.01           NaN
# 16526      0.00      0.00         0.00          0.01          55.0
#
#        Critic_Count  User_Score  User_Count                     Developer  \
# 183            29.0         8.5       140.0                    EA Tiburon
# 377            20.0         6.4        76.0                     EA Canada
# 456            17.0         7.9        22.0             Traveller's Tales
# 475             NaN         NaN         NaN                           NaN
# 609             NaN         NaN         NaN                           NaN
# ...             ...         ...         ...                           ...
# 16376           7.0         NaN         NaN            Oxygen Interactive
# 16409          14.0         6.5         6.0                        Midway
# 16452           6.0         6.7       107.0             Saber Interactive
# 16462           NaN         NaN         NaN                           NaN
# 16526          19.0         5.5        12.0  Artificial Mind and Movement
#
#       Rating
# 183        E
# 377        E
# 456     E10+
# 475      NaN
# 609      NaN
# ...      ...
# 16376   E10+
# 16409      T
# 16452      M
# 16462    NaN
# 16526      T
#
# [269 rows x 16 columns]

# %%
crit = 8137 / 16715
user = 10014 / 16715
rate = 9949 / 16715
print('Доля пропущенных значений в:\n"critic_score" - {:.1%},\n"user_score" --- {:.1%}, \n"rating" ------- {:.1%}'
      .format(crit, user, rate))
# Out:
# Доля пропущенных значений в:
# "critic_score" - 48.7%,
# "user_score" --- 59.9%,
# "rating" ------- 59.5%

# %%
games.columns = games.columns.str.lower()
games.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'publisher', 'na_sales',
#        'eu_sales', 'jp_sales', 'other_sales', 'global_sales', 'critic_score',
#        'critic_count', 'user_score', 'user_count', 'developer', 'rating'],
#       dtype='object')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16717 non-null  object
#  1   platform         16719 non-null  object
#  2   year_of_release  16450 non-null  float64
#  3   genre            16717 non-null  object
#  4   publisher        16665 non-null  object
#  5   na_sales         16719 non-null  float64
#  6   eu_sales         16719 non-null  float64
#  7   jp_sales         16719 non-null  float64
#  8   other_sales      16719 non-null  float64
#  9   global_sales     16719 non-null  float64
#  10  critic_score     8137 non-null   float64
#  11  critic_count     8137 non-null   float64
#  12  user_score       7590 non-null   float64
#  13  user_count       7590 non-null   float64
#  14  developer        10096 non-null  object
#  15  rating           9950 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %%
games.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   publisher  na_sales  eu_sales  jp_sales  other_sales  global_sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.68     12.76      3.79         3.29         35.52
# 3  Nintendo     15.61     10.93      3.28         2.95         32.77
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
# 5  Nintendo     23.20      2.26      4.22         0.58         30.26
# 6  Nintendo     11.28      9.14      6.50         2.88         29.80
# 7  Nintendo     13.96      9.18      2.93         2.84         28.92
# 8  Nintendo     14.44      6.94      4.70         2.24         28.32
# 9  Nintendo     26.93      0.63      0.28         0.47         28.31
#
#    critic_score  critic_count  user_score  user_count developer rating
# 0          76.0          51.0         8.0       322.0  Nintendo      E
# 1           NaN           NaN         NaN         NaN       NaN    NaN
# 2          82.0          73.0         8.3       709.0  Nintendo      E
# 3          80.0          73.0         8.0       192.0  Nintendo      E
# 4           NaN           NaN         NaN         NaN       NaN    NaN
# 5           NaN           NaN         NaN         NaN       NaN    NaN
# 6          89.0          65.0         8.5       431.0  Nintendo      E
# 7          58.0          41.0         6.6       129.0  Nintendo      E
# 8          87.0          80.0         8.4       594.0  Nintendo      E
# 9           NaN           NaN         NaN         NaN       NaN    NaN

# %%
for column in games[['name','platform','genre','rating']]:
    games[column] = games[column].str.lower()

# %%
games['year_of_release'] = games['year_of_release'].astype('Int64')

# %%
games.sample(20)
# Out:
#                                                     name platform  \
# 14818                                 dream girl premier      3ds
# 7972                               rango: the video game      ps3
# 14673  royal palace of white sword and the city of ge...       pc
# 615                                       dragon warrior      nes
# 4343                                  singstar take that      ps2
# 14003                                         dt carnage      psp
# 4676                                farming simulator 17      ps4
# 7267                                             nfl 2k3       gc
# 14705                                           whiteout       xb
# 8047        hatsune miku and future stars: project mirai      3ds
# 8289   broken sword: shadows of the templars - the di...       ds
# 9304                                legends of wrestling       xb
# 8233                                            race pro     x360
# 16124               himawari: pebble in the sky portable      psp
# 3077           disney's kim possible 2: drakken's demise      gba
# 2895                                                 ssx     x360
# 14862                                     under the skin      ps2
# 1728                                 mission: impossible      n64
# 9269                                lips: i love the 80s     x360
# 15591                                       elven legacy       pc
#
#        year_of_release         genre                     publisher  na_sales  \
# 14818             2015          misc                     Alchemist      0.00
# 7972              2011        action               Electronic Arts      0.07
# 14673             2009  role-playing          Take-Two Interactive      0.00
# 615               1986  role-playing                        Capcom      0.49
# 4343              2009          misc   Sony Computer Entertainment      0.00
# 14003             2009        racing                        Agetec      0.03
# 4676              2016    simulation        Focus Home Interactive      0.05
# 7267              2002        sports                          Sega      0.17
# 14705             2002        racing  Konami Digital Entertainment      0.02
# 8047              2012          misc                          Sega      0.00
# 8289              2009     adventure                       Ubisoft      0.07
# 9304              2002      fighting         Acclaim Entertainment      0.10
# 8233              2009        racing                         Atari      0.06
# 16124             2010     adventure               Kadokawa Shoten      0.00
# 3077              2004      platform    Disney Interactive Studios      0.47
# 2895              2012        sports               Electronic Arts      0.38
# 14862             2004        action                        Capcom      0.01
# 1728              1997        action                         Ocean      0.74
# 9269              2010          misc        Microsoft Game Studios      0.00
# 15591             2009      strategy           Paradox Interactive      0.02
#
#        eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 14818      0.00      0.03         0.00          0.03           NaN
# 7972       0.09      0.00         0.03          0.19          65.0
# 14673      0.02      0.00         0.00          0.03           NaN
# 615        0.00      0.52         1.51          2.52           NaN
# 4343       0.06      0.00         0.39          0.45           NaN
# 14003      0.00      0.00         0.00          0.04           NaN
# 4676       0.31      0.00         0.06          0.41          69.0
# 7267       0.04      0.00         0.01          0.22          92.0
# 14705      0.01      0.00         0.00          0.03          58.0
# 8047       0.00      0.18         0.00          0.18           NaN
# 8289       0.08      0.00         0.02          0.17           NaN
# 9304       0.03      0.00         0.00          0.14          65.0
# 8233       0.09      0.00         0.02          0.17          72.0
# 16124      0.00      0.01         0.00          0.01           NaN
# 3077       0.17      0.00         0.01          0.66          77.0
# 2895       0.26      0.00         0.06          0.70          82.0
# 14862      0.01      0.00         0.00          0.03          55.0
# 1728       0.38      0.02         0.03          1.17           NaN
# 9269       0.12      0.00         0.02          0.14           NaN
# 15591      0.00      0.00         0.00          0.02          71.0
#
#        critic_count  user_score  user_count                     developer  \
# 14818           NaN         NaN         NaN                           NaN
# 7972           23.0         6.4         7.0         Behaviour Interactive
# 14673           NaN         NaN         NaN                           NaN
# 615             NaN         NaN         NaN                           NaN
# 4343            NaN         NaN         NaN                           NaN
# 14003           NaN         NaN         NaN            Axis Entertainment
# 4676           17.0         8.7        12.0                 Maximum Games
# 7267           24.0         8.3        15.0               Visual Concepts
# 14705           4.0         NaN         NaN                        Konami
# 8047            NaN         NaN         NaN                           NaN
# 8289            NaN         NaN         NaN                           NaN
# 9304           10.0         5.8         4.0                       Acclaim
# 8233           54.0         7.0        60.0                        SimBin
# 16124           NaN         NaN         NaN                           NaN
# 3077            8.0         NaN         NaN  Artificial Mind and Movement
# 2895           65.0         6.4       186.0                     EA Canada
# 14862          30.0         NaN         NaN                        Capcom
# 1728            NaN         NaN         NaN                           NaN
# 9269            NaN         NaN         NaN                           NaN
# 15591          27.0         7.1        38.0                     1C:Ino-Co
#
#       rating
# 14818    NaN
# 7972    e10+
# 14673    NaN
# 615      NaN
# 4343     NaN
# 14003   e10+
# 4676       e
# 7267       e
# 14705      t
# 8047     NaN
# 8289     NaN
# 9304       t
# 8233       e
# 16124    NaN
# 3077       e
# 2895       e
# 14862      t
# 1728     NaN
# 9269     NaN
# 15591      t

# %%
games['year_of_release'].isna().sum()
# Out:
# 269

# %%
games.query('name == "madden nfl 2004"')
# Out:
#                  name platform  year_of_release   genre        publisher  \
# 183   madden nfl 2004      ps2             <NA>  sports  Electronic Arts
# 1881  madden nfl 2004       xb             2003  sports  Electronic Arts
# 3889  madden nfl 2004       gc             2003  sports  Electronic Arts
# 5708  madden nfl 2004      gba             2003  sports  Electronic Arts
#
#       na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 183       4.26      0.26      0.01         0.71          5.23          94.0
# 1881      1.02      0.02      0.00         0.05          1.09          92.0
# 3889      0.40      0.10      0.00         0.01          0.51          94.0
# 5708      0.22      0.08      0.00         0.01          0.31          70.0
#
#       critic_count  user_score  user_count   developer rating
# 183           29.0         8.5       140.0  EA Tiburon      e
# 1881          27.0         8.3        48.0  EA Tiburon      e
# 3889          19.0         7.7        17.0  EA Tiburon      e
# 5708           9.0         6.6         5.0      BudCat      e

# %%
for i in games[games['year_of_release'].isnull() == True].index:  
    games['year_of_release'][i] = games.loc[games['name'] == games['name'][i], 'year_of_release'].max()

# %%
games['year_of_release'].isna().sum()
# Out:
# 146

# %%
games['user_score'] = games['user_score'].replace('tbd', np.nan, regex=True)

# %%
games['user_score'] = games['user_score'].astype(float)
games['user_score'].dtype
# Out:
# dtype('float64')

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %%
games
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         wii sports      wii             2006        sports
# 1                  super mario bros.      nes             1985      platform
# 2                     mario kart wii      wii             2008        racing
# 3                  wii sports resort      wii             2009        sports
# 4           pokemon red/pokemon blue       gb             1996  role-playing
# ...                              ...      ...              ...           ...
# 16714  samurai warriors: sanada maru      ps3             2016        action
# 16715               lma manager 2007     x360             2006        sports
# 16716        haitaka no psychedelica      psv             2016     adventure
# 16717               spirits & spells      gba             2003      platform
# 16718            winning post 8 2016      psv             2016    simulation
#
#           publisher  na_sales  eu_sales  jp_sales  other_sales  global_sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        critic_score  critic_count  user_score  user_count developer rating  \
# 0              76.0          51.0         8.0       322.0  Nintendo      e
# 1               NaN           NaN         NaN         NaN       NaN    NaN
# 2              82.0          73.0         8.3       709.0  Nintendo      e
# 3              80.0          73.0         8.0       192.0  Nintendo      e
# 4               NaN           NaN         NaN         NaN       NaN    NaN
# ...             ...           ...         ...         ...       ...    ...
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN
#
#        total_sales
# 0            82.54
# 1            40.24
# 2            35.52
# 3            32.77
# 4            31.38
# ...            ...
# 16714         0.01
# 16715         0.01
# 16716         0.01
# 16717         0.01
# 16718         0.01
#
# [16719 rows x 17 columns]

# %%
games_by_each_year = games.pivot_table(index='year_of_release', values='name', aggfunc='count')
plt.figure(figsize=(12,6))
sns.lineplot(data=games_by_each_year)
sns.set_style('darkgrid')
plt.title("Количество игр по годам")
plt.xlabel("Год выпуска")
plt.ylabel("Количество выпущенных игр")
plt.legend('')

# %%
def create_any_bar(groupby_column, func, y='name'):
    plt.style.use('seaborn-pastel')
    df_to_plot = games.groupby(groupby_column)[y]
    if func == 'count':
        df_to_plot_calculated = df_to_plot.count()
        figsize = (15,5)
        plot = df_to_plot_calculated.plot(kind='bar', y=y, figsize=figsize, ec='black')
    elif func == 'sum':
        df_to_plot_calculated = df_to_plot.sum().sort_values()
        figsize = (15,10)
        plot = df_to_plot_calculated.plot(kind='barh', y=y, figsize=figsize, ec='black')

# %%
create_any_bar('year_of_release', 'count')

# %%
sales_on_platform = games.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False)

plt.figure(figsize=(13,4))
sns.barplot(x=sales_on_platform.index,y=sales_on_platform['total_sales'])
plt.title("Продажи по платформам за весь период")
plt.xlabel("Название платформы")
plt.ylabel("Количество продаж")
# Out:
# Text(0, 0.5, 'Количество продаж')

# %%
platform_grouped = sales_on_platform.reset_index()

# %%
top_platforms_list = platform_grouped['platform'].unique()
top_platforms_list
# Out:
# array(['ps2', 'x360', 'ps3', 'wii', 'ds', 'ps', 'gba', 'ps4', 'psp', 'pc',
#        '3ds', 'xb', 'gb', 'nes', 'n64', 'snes', 'gc', 'xone', '2600',
#        'wiiu', 'psv', 'sat', 'gen', 'dc', 'scd', 'ng', 'ws', 'tg16',
#        '3do', 'gg', 'pcfx'], dtype=object)

# %%
for platform in top_platforms_list:
    games[games['platform'] == platform].pivot_table(index='year_of_release', values='total_sales', aggfunc='sum').plot(
        kind='bar', figsize=(13,4))
    plt.title(platform)
# Out:
# C:\Users\Honor\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
top_3_platforms = games.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False).head(3)
top_3_platforms = top_3_platforms.reset_index().rename_axis(None, axis=1)

# %%
top_3_platforms
# Out:
#   platform  total_sales
# 0      ps2      1255.77
# 1     x360       971.42
# 2      ps3       939.65

# %%
decline_period_data = games[games['year_of_release'] > 2009]
decline_period_data
# Out:
#                                  name platform  year_of_release         genre  \
# 14                 kinect adventures!     x360             2010          misc
# 16                 grand theft auto v      ps3             2013        action
# 23                 grand theft auto v     x360             2013        action
# 27        pokemon black/pokemon white       ds             2010  role-playing
# 29     call of duty: modern warfare 3     x360             2011       shooter
# ...                               ...      ...              ...           ...
# 16707                strawberry nauts      psv             2016     adventure
# 16711                aiyoku no eustia      psv             2014          misc
# 16714   samurai warriors: sanada maru      ps3             2016        action
# 16716         haitaka no psychedelica      psv             2016     adventure
# 16718             winning post 8 2016      psv             2016    simulation
#
#                     publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 14     Microsoft Game Studios     15.00      4.89      0.24         1.69
# 16       Take-Two Interactive      7.02      9.09      0.98         3.96
# 23       Take-Two Interactive      9.66      5.14      0.06         1.41
# 27                   Nintendo      5.51      3.17      5.65         0.80
# 29                 Activision      9.04      4.24      0.13         1.32
# ...                       ...       ...       ...       ...          ...
# 16707                 Unknown      0.00      0.00      0.01         0.00
# 16711         dramatic create      0.00      0.00      0.01         0.00
# 16714              Tecmo Koei      0.00      0.00      0.01         0.00
# 16716            Idea Factory      0.00      0.00      0.01         0.00
# 16718              Tecmo Koei      0.00      0.00      0.01         0.00
#
#        global_sales  critic_score  critic_count  user_score  user_count  \
# 14            21.81          61.0          45.0         6.3       106.0
# 16            21.04          97.0          50.0         8.2      3994.0
# 23            16.27          97.0          58.0         8.1      3711.0
# 27            15.14           NaN           NaN         NaN         NaN
# 29            14.73          88.0          81.0         3.4      8713.0
# ...             ...           ...           ...         ...         ...
# 16707          0.01           NaN           NaN         NaN         NaN
# 16711          0.01           NaN           NaN         NaN         NaN
# 16714          0.01           NaN           NaN         NaN         NaN
# 16716          0.01           NaN           NaN         NaN         NaN
# 16718          0.01           NaN           NaN         NaN         NaN
#
#                                developer rating  total_sales
# 14                   Good Science Studio      e        21.82
# 16                        Rockstar North      m        21.05
# 23                        Rockstar North      m        16.27
# 27                                   NaN    NaN        15.13
# 29     Infinity Ward, Sledgehammer Games      m        14.73
# ...                                  ...    ...          ...
# 16707                                NaN    NaN         0.01
# 16711                                NaN    NaN         0.01
# 16714                                NaN    NaN         0.01
# 16716                                NaN    NaN         0.01
# 16718                                NaN    NaN         0.01
#
# [5327 rows x 17 columns]

# %%
list_of_top_6 = ['ps4','xone','pc','wiiu','3ds', 'psv']
games_top_6_platforms = decline_period_data[decline_period_data['platform'].isin(['ps4','xone','pc','wiiu','3ds', 'psv'])]
games_top_6_platforms = games_top_6_platforms[games_top_6_platforms['total_sales']<1.4]

# %%
games_top_6_platforms['total_sales'].describe()
# Out:
# count    2054.000000
# mean        0.206573
# std         0.271136
# min         0.010000
# 25%         0.030000
# 50%         0.090000
# 75%         0.260000
# max         1.390000
# Name: total_sales, dtype: float64

# %%
games_top_6_platforms.groupby('platform')['total_sales'].describe()
# Out:
#           count      mean       std   min   25%   50%     75%   max
# platform
# 3ds       480.0  0.215146  0.266073  0.01  0.04  0.11  0.2625  1.39
# pc        469.0  0.171002  0.237493  0.01  0.03  0.07  0.2000  1.36
# ps4       327.0  0.257890  0.298184  0.01  0.05  0.12  0.3600  1.32
# psv       428.0  0.114159  0.168307  0.01  0.02  0.05  0.1300  1.31
# wiiu      135.0  0.294222  0.302792  0.01  0.07  0.19  0.4200  1.30
# xone      215.0  0.315907  0.364930  0.01  0.05  0.16  0.4550  1.39

# %%
distr_genre = games_top_6_platforms.pivot_table(index='genre', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False).reset_index().rename_axis(None, axis=1)
distr_genre
# Out:
#            genre  total_sales
# 0         action       140.94
# 1   role-playing        64.68
# 2        shooter        45.27
# 3         sports        43.31
# 4           misc        25.83
# 5      adventure        18.22
# 6       platform        17.95
# 7     simulation        17.60
# 8         racing        16.55
# 9       fighting        15.48
# 10      strategy        12.51
# 11        puzzle         5.96

# %%
plt.figure(figsize=(12,6))
plt.title('Распределение игр по жанрам ',fontsize=15)
sns.barplot(data=distr_genre, x='genre', y='total_sales')
plt.xlabel('Жанры игр',fontsize=12)
plt.ylabel('Продажи',fontsize=12)
# Out:
# Text(0, 0.5, 'Продажи')

# %%
#Функция для создания сводбных таблиц за весь период
def user_portrait(row, title):
    fig, axes = plt.subplots(1, 3, figsize=(20, 4))
    for pivot, ax in zip(list(['platform','genre','rating']),axes):
        ppivot = games.pivot_table(index=pivot, values=row, aggfunc='sum'
                  ).sort_values(by=row, ascending=False).reset_index().rename_axis(None, axis=1).head(5)
        display(ppivot)
 
        sns.set_palette("Blues")
        sns.barplot(data=ppivot, x=pivot, y=row, ax=ax)
        fig.suptitle(title, fontsize=15)
        

plt.show()
sns.set()

#Функция для создания сводных таблиц за последний год
def user_portrait_2016(row, title):
    temp = games[games['year_of_release']>2015]
    fig, axes = plt.subplots(1, 3, figsize=(20, 4))
    for pivot, ax in zip(list(['platform','genre','rating']), axes):
        ppivot = temp.pivot_table(index=pivot, values=row, aggfunc='sum').sort_values(by=row, ascending=False).reset_index().rename_axis(None, axis=1).head(5)
        display(ppivot)

        sns.set_palette("BuGn_r")
        sns.barplot(data=ppivot, x=pivot, y=row, ax=ax)
        fig.suptitle(title, fontsize=15)

# %%
user_portrait('na_sales','Топ 5 платформ, жанров и рейтингов за весь период')
# Out:
#   platform  na_sales
# 0     x360    602.47
# 1      ps2    583.84
# 2      wii    496.90
# 3      ps3    393.49
# 4       ds    382.67
#       genre  na_sales
# 0    action    879.01
# 1    sports    684.43
# 2   shooter    592.24
# 3  platform    445.50
# 4      misc    407.27
#   rating  na_sales
# 0      e   1293.26
# 1      t    759.75
# 2      m    748.48
# 3   e10+    353.32
# 4    k-a      2.56

# %%
user_portrait_2016('na_sales','Топ 5 платформ, жанров и рейтингов за последний год')
# Out:
#   platform  na_sales
# 0      ps4     21.49
# 1     xone     14.27
# 2      3ds      4.14
# 3     wiiu      2.10
# 4       pc      1.36
#           genre  na_sales
# 0       shooter     16.24
# 1        action      9.29
# 2        sports      7.54
# 3  role-playing      5.89
# 4      fighting      1.84
#   rating  na_sales
# 0      m     15.67
# 1      t      8.95
# 2      e      8.24
# 3   e10+      3.81

# %%
#Выведем топ 5 платформ, жанров и рейтингов за весь период
user_portrait('eu_sales','Топ 5 платформ, жанров и рейтингов за весь период')
# Out:
#   platform  eu_sales
# 0      ps2    339.29
# 1      ps3    330.29
# 2     x360    270.76
# 3      wii    262.21
# 4       ps    213.61
#      genre  eu_sales
# 0   action    519.13
# 1   sports    376.79
# 2  shooter    317.34
# 3   racing    236.51
# 4     misc    212.74
#   rating  eu_sales
# 0      e    710.25
# 1      m    483.97
# 2      t    427.03
# 3   e10+    188.52
# 4     ao      0.61

# %%
#Выведем топ 5 платформ, жанров и рейтингов за последний год
user_portrait_2016('eu_sales','Топ 5 платформ, жанров и рейтингов за последний год')
# Out:
#   platform  eu_sales
# 0      ps4     31.78
# 1     xone      9.63
# 2       pc      3.53
# 3      3ds      2.33
# 4     wiiu      1.48
#           genre  eu_sales
# 0       shooter     15.90
# 1        sports     12.01
# 2        action     10.68
# 3  role-playing      4.28
# 4        racing      1.77
#   rating  eu_sales
# 0      m     16.54
# 1      e     13.61
# 2      t      9.79
# 3   e10+      3.81

# %%
#Выведем топ 5 платформ, жанров и рейтингов за весь период
user_portrait('jp_sales','Топ 5 платформ, жанров и рейтингов за весь период')
# Out:
#   platform  jp_sales
# 0       ds    175.57
# 1       ps    139.82
# 2      ps2    139.20
# 3     snes    116.55
# 4      3ds    100.67
#           genre  jp_sales
# 0  role-playing    355.46
# 1        action    161.44
# 2        sports    135.54
# 3      platform    130.83
# 4          misc    108.11
#   rating  jp_sales
# 0      e    198.11
# 1      t    151.40
# 2      m     64.24
# 3   e10+     40.20
# 4    k-a      1.46

# %%
#Выведем топ 5 платформ, жанров и рейтингов за последний год
user_portrait_2016('jp_sales','Топ 5 платформ, жанров и рейтингов за весь период')
# Out:
#   platform  jp_sales
# 0      3ds      8.03
# 1      ps4      5.78
# 2      psv      3.58
# 3      ps3      1.30
# 4     wiiu      0.67
#           genre  jp_sales
# 0        action      7.08
# 1  role-playing      6.66
# 2     adventure      1.18
# 3       shooter      1.06
# 4          misc      1.04
#   rating  jp_sales
# 0      t      2.27
# 1      m      1.20
# 2      e      1.07
# 3   e10+      0.45
